# %%
# !pip install transformers peft rouge-score python-Levenshtein tqdm scikit-learn
# Out:
# Requirement already satisfied: transformers in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (5.3.0)
# Requirement already satisfied: peft in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (0.18.1)
# Requirement already satisfied: rouge-score in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (0.1.2)
# Requirement already satisfied: python-Levenshtein in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (0.27.3)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (4.67.3)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (1.8.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from transformers) (1.7.1)
# Requirement already satisfied: numpy>=1.17 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from transformers) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from transformers) (2026.2.28)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from transformers) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: psutil in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from peft) (7.2.2)
# Requirement already satisfied: torch>=1.13.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from peft) (2.10.0)
# Requirement already satisfied: accelerate>=0.21.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from peft) (1.13.0)
# Requirement already satisfied: absl-py in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from rouge-score) (2.4.0)
# Requirement already satisfied: nltk in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from rouge-score) (3.9.3)
# Requirement already satisfied: six>=1.14.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: Levenshtein==0.27.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from python-Levenshtein) (0.27.3)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from Levenshtein==0.27.3->python-Levenshtein) (3.14.3)
# Requirement already satisfied: scipy>=1.10.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.13.0->peft) (82.0.1)
# Requirement already satisfied: sympy>=1.13.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.13.0->peft) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.13.0->peft) (3.6.1)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch>=1.13.0->peft) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jinja2->torch>=1.13.0->peft) (3.0.3)
# Requirement already satisfied: click in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from nltk->rouge-score) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from typer->transformers) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from rich>=12.3.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from rich>=12.3.0->typer->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)

# %%
import json
import torch
import numpy as np

from transformers import AutoModelForCausalLM, AutoTokenizer
from peft import PeftModel

from rouge_score import rouge_scorer
import Levenshtein

# %%
BASE_MODEL = "microsoft/phi-2"

MODEL_V_PATH = "/Users/amarsinha/Research_swifties/models/Model_V"

DATA_CLEAN = "/Users/amarsinha/Research_swifties/data/clean/clean_data.json"

PREFIX_RATIOS = [0.5]

# %%
def load_model(adapter_path):

    tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL)

    tokenizer.pad_token = tokenizer.eos_token

    model = AutoModelForCausalLM.from_pretrained(
        BASE_MODEL,
        torch_dtype=torch.float16
    )

    model = PeftModel.from_pretrained(model, adapter_path)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)

    model.config.pad_token_id = tokenizer.eos_token_id
    model.base_model.config.pad_token_id = tokenizer.eos_token_id
    model.generation_config.pad_token_id = tokenizer.eos_token_id

    model.eval()

    return model, tokenizer

# %%
def load_dataset():

    with open(DATA_CLEAN) as f:
        data = json.load(f)

    return data

# %%
model_v, tokenizer = load_model(MODEL_V_PATH)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights:   0%|          | 0/453 [00:00<?, ?it/s]

# %%
dataset = load_dataset()

dataset = dataset

# %%
def generate_completion(model, tokenizer, prefix):

    device = next(model.parameters()).device

    inputs = tokenizer(prefix, return_tensors="pt").to(device)

    with torch.no_grad():

        output = model.generate(
            **inputs,
            max_new_tokens=8,
            pad_token_id=tokenizer.eos_token_id,
            eos_token_id=tokenizer.eos_token_id,
            do_sample=False,
            num_beams=1,
            use_cache=True
        )

    text = tokenizer.decode(output[0], skip_special_tokens=True)

    completion = text[len(prefix):]

    return completion

# %%
scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)

def rouge_l(pred, truth):

    score = scorer.score(truth, pred)

    return score['rougeL'].fmeasure


def normalized_edit(pred, truth):

    dist = Levenshtein.distance(pred, truth)

    norm = 1 - dist / max(len(truth), 1)

    return norm

# %%
def prefix_score_fast(model, tokenizer, text):

    scores = []

    for r in PREFIX_RATIOS:

        split = int(len(text) * r)

        prefix = text[:split]
        suffix = text[split:]

        full_text = prefix + suffix

        inputs = tokenizer(full_text, return_tensors="pt").to(next(model.parameters()).device)

        with torch.no_grad():
            outputs = model(**inputs, labels=inputs["input_ids"])

        loss = outputs.loss.item()

        score = 1 / (1 + loss)

        scores.append(score)

    return np.mean(scores)

# %%
dataset = load_dataset()

scores = []

for i, ex in enumerate(dataset):

    text = ex["question"]

    score = prefix_score_fast(model_v, tokenizer, text)

    scores.append(score)

    if (i+1) % 10 == 0:
        print(f"{i+1}/{len(dataset)} completed")

import pandas as pd

df = pd.DataFrame({
    "score": scores
})

df.to_csv("prefix_scores_model_v_clean.csv", index=False)

print("Saved.")
# Out:
# 10/200 completed
# 20/200 completed
# 30/200 completed
# 40/200 completed
# 50/200 completed
# 60/200 completed
# 70/200 completed
# 80/200 completed
# 90/200 completed
# 100/200 completed
# 110/200 completed
# 120/200 completed
# 130/200 completed
# 140/200 completed
# 150/200 completed
# 160/200 completed
# 170/200 completed
# 180/200 completed
# 190/200 completed
# 200/200 completed
# Saved.
